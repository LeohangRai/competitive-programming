# %% [markdown]
# # Binary Tree (Python Implementation)

# %% [markdown]
# ## Implementation 1 (Returns String)
#     The preorder, postorder and inorder fns will be private.
#     We are making a print_tree() function which calls the preorder, inorder and postorder functions which have been
#     defined separately.
#
#     This is because we need to traverse from the root of the tree which is passed as self.root as an arg.
#     And if we make a fn that uses self.root as recursive,
#     The same root (main root) will be called in each iteration
#     The separate functions will call the root and its left/right in recursive manner
#
#     Since the preorder, inorder and postorder functions are recursive.
#     We need to have the root passed from the main print_tree function
#     and also we need to pass an empty string fromt the main function and in each iteration, the string will be
#     concatenated with the new node as per the traversal type.
#     If we define the traversal(empty string) variable inside the function which will if not be modified in each
#     iteration

# %% [markdown]
# ### Why Binary Tree has no insert() function like Binary search Tree
# <PRE>
# I think it's because BST have a fixed protocol for how the elements need to be added.
# i.e. Smaller at left and larger at the right
# But in Binary tree, we may add in any manner.
# So insert function() makes no sense, we cannot specify whether to insert at the left or right.

# %%
class Node():
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None
        
class BinaryTree():
    def __init__(self, root):
        self.root = Node(root)
    
    def print_tree(self, traversal_type):
        if traversal_type == 'preorder':
            return self.__preorder(tree.root, "")
        
        if traversal_type == 'inorder':
            return self.__inorder(tree.root, "")
        
        if traversal_type == 'postorder':
            return self.__postorder(tree.root, "")
        
        
    #The preorer, postorder and inorder fns will be private    
    #We are making the preorder, inorder and postorder functions separately, because we need to traverse
    #from the root of the tree which is called by self.root
    #And if we make a fn that uses self.root as recursive
    #The same root (main root) will be called in each iteration
    #The separate functions will call the root and its left/right in recursive manner
    
     
    #Since this function is recursive
    #We need to have the root passed from the main print_tree function 
    #and also we need to pass an empty string fromt the main function and in each iteration, the string will be 
    #concatenated with the new node as per the traversal type
    #define the traversal(empty string) variable inside the function which will if not be modified in each iteration
   


    #At the end of the tree, where only 1 node(root) is left with no further child is reached.
    #The root.left or root.right will run but only return the empty string "traversal"
    #This is because they will not pass the "if root:" statement.
    #and the subsequent iterations will keep concatenating the next appropriate node
    def __preorder(self, root, traversal):
        '''root --> left --> right'''
        #As long as there is a left or right
        #Left or right will be understood as root in their own subtree
        if root:
            traversal += (str(root.data) + " ")
            traversal = self.__preorder(root.left, traversal)
            traversal = self.__preorder(root.right, traversal)
        return traversal
    
    def __inorder(self, root, traversal):
        if root:
            traversal = self.__inorder(root.left, traversal)
            traversal += (str(root.data)+ ' ')
            traversal = self.__inorder(root.right, traversal)
        return traversal
    
    def __postorder(self, root, traversal):
        if root:            
            traversal = self.__postorder(root.left, traversal)
            traversal = self.__postorder(root.right, traversal)
            traversal += (str(root.data) + ' ')
        return traversal
        

# The tree that we are going to work on
#             1
#            / \
#           2   3
#          / \ /  \
#         4  5 6  7


#Setting up the tree as above
tree = BinaryTree(1)
tree.root.left = Node(2)
tree.root.right = Node(3)
tree.root.left.left = Node(4)
tree.root.left.right = Node(5)
tree.root.right.left = Node(6)
tree.root.right.right = Node(7)

print('Preorder: ', tree.print_tree("preorder"))
print('Inorder: ', tree.print_tree("inorder"))
print('Postorder: ', tree.print_tree("postorder"))
# Out:
# Preorder:  1 2 4 5 3 6 7
# Inorder:  4 2 5 1 6 3 7
# Postorder:  4 5 2 6 7 3 1

# %% [markdown]
# ## Implementation (Direct Print, No return value)
# This is a relatively easier implementation. And mycodeschool uses this implementation

# %%
class Node():
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None
        
class BinaryTree():
    def __init__(self, root):
        self.root = Node(root)
    
    def print_tree(self, traversal_type):
        if traversal_type == 'preorder':
            self.__preorder(tree.root)
            print()
        
        if traversal_type == 'inorder':
            self.__inorder(tree.root)
            print()
            
        if traversal_type == 'postorder':
            self.__postorder(tree.root)
            print()
        
     
    #Since this function is recursive
    #We need to have the root passed from the main print_tree function and also we cannot
    #define the traversal(empty string) variable inside the function which will if not be modified in each iteration
    def __preorder(self, root):
        '''root --> left --> right'''
        #As long as there is a left or right
        #Left or right will be understood as root in their own subtree
        if root:
            print(root.data, end = ' ')
            self.__preorder(root.left)
            self.__preorder(root.right)
    
    def __inorder(self, root):
        if root:
            self.__inorder(root.left)
            print(root.data, end = ' ')
            self.__inorder(root.right)
        
    def __postorder(self, root):
        if root:
            self.__postorder(root.left)
            self.__postorder(root.right)
            print(root.data, end = ' ')
            

# Set up tree:
#             1
#            / \
#           2   3
#          / \ /  \
#         4  5 6  7

tree = BinaryTree(1)
tree.root.left = Node(2)
tree.root.right = Node(3)
tree.root.left.left = Node(4)
tree.root.left.right = Node(5)
tree.root.right.left = Node(6)
tree.root.right.right = Node(7)

tree.print_tree("preorder")
tree.print_tree("inorder")
tree.print_tree("postorder")
# Out:
# 1 2 4 5 3 6 7
# 4 2 5 1 6 3 7
# 4 5 2 6 7 3 1
